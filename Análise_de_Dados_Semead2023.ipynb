# %% [markdown]
# <a href="https://colab.research.google.com/github/daniel-usp/USP/blob/main/An%C3%A1lise_de_Dados_Semead2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Banco de dados do ENEM 2019

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

fonte = "https://github.com/daniel-usp/LIT/blob/master/Enem_2019.csv?raw=true"
dados = pd.read_csv(fonte)
dados
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0       190001004661    2019                  1506138                Redenção
# 1       190001004674    2019                  1504208                  Marabá
# 2       190001004722    2019                  1501402                   Belém
# 3       190001004735    2019                  1507300      São Félix do Xingu
# 4       190001004776    2019                  1500800              Ananindeua
# ...              ...     ...                      ...                     ...
# 127375  190006120035    2019                  3142700             Montalvânia
# 127376  190006120036    2019                  2902807         Barra da Estiva
# 127377  190006120037    2019                  2927408                Salvador
# 127378  190006120060    2019                  2930709            Simões Filho
# 127379  190006120170    2019                  3106200          Belo Horizonte
#
# ...

# %%
qtde_alunos_estado = dados['SG_UF_RESIDENCIA'].value_counts()
qtde_alunos_estado
# Out:
# SP    20264
# MG    13547
# BA    10040
# RJ     8467
# CE     7381
# PA     7170
# PE     6941
# MA     5543
# RS     5466
# PR     5259
# GO     4268
# PB     3690
# PI     3034
# RN     2959
# AM     2820
# SC     2673
# ES     2550
# DF     2408
# AL     2263
# MT     2230
# SE     1815
# MS     1655
# RO     1400
# TO     1178
# AP     1047
# AC      946
# RR      366
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
dados.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        'TP_NACIONALIDADE', 'CO_MUNICIPIO_NASCIMENTO',
#        'NO_MUNICIPIO_NASCIMENTO', 'CO_UF_NASCIMENTO', 'SG_UF_NASCIMENTO',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_ESCOLA', 'CO_MUNICIPIO_ESC',
#        'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC',
#        'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
#        'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ',
#        'IN_DEFICIENCIA_AUDITIVA', 'IN_SURDO_CEGUEIRA',
#        'IN_DEFICIENCIA_FISICA', 'IN_DEFICIENCIA_MENTAL',
#        'IN_DEFICIT_ATENCAO', 'IN_DISLEXIA', 'IN_DISCALCULIA',
#        'IN_AUTISMO', 'IN_VISAO_MONOCULAR', 'IN_OUTRA_DEF', 'IN_GESTANTE',
#        'IN_LACTANTE', 'IN_IDOSO', 'IN_ESTUDA_CLASSE_HOSPITALAR',
# ...

# %%
colunas = ['SG_UF_RESIDENCIA', 'Q025']
dados[colunas]
# Out:
#        SG_UF_RESIDENCIA Q025
# 0                    PA    B
# 1                    PA    B
# 2                    PA    B
# 3                    PA    B
# 4                    PA    B
# ...                 ...  ...
# 127375               MG    B
# 127376               BA    B
# 127377               BA    B
# 127378               BA    A
# 127379               MG    B
#
# [127380 rows x 2 columns]

# %%
dados['SG_UF_RESIDENCIA'].unique()
# Out:
# array(['PA', 'RO', 'MT', 'AC', 'AM', 'RR', 'MA', 'PR', 'BA', 'PI', 'CE',
#        'PE', 'AP', 'TO', 'SC', 'GO', 'MG', 'SP', 'SE', 'RJ', 'PB', 'AL',
#        'RN', 'ES', 'DF', 'RS', 'MS'], dtype=object)

# %%
frequencia = dados['SG_UF_RESIDENCIA'].value_counts()
print(frequencia)
# Out:
# SP    20264
# MG    13547
# BA    10040
# RJ     8467
# CE     7381
# PA     7170
# PE     6941
# MA     5543
# RS     5466
# PR     5259
# GO     4268
# PB     3690
# PI     3034
# RN     2959
# AM     2820
# SC     2673
# ES     2550
# DF     2408
# AL     2263
# MT     2230
# SE     1815
# MS     1655
# RO     1400
# TO     1178
# AP     1047
# AC      946
# RR      366
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
contador_idade = dados['NU_IDADE'].value_counts().sort_index()
print(contador_idade)
# Out:
# 13        4
# 14      141
# 15     2009
# 16     7830
# 17    21256
#       ...
# 73        2
# 75        2
# 76        1
# 77        1
# 82        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %%
#Perguntar no ChatGPT - Com base no comando: dados['NU_IDADE'].value_counts()
#Colocar o índice dos resultador em ordem crescente
# Out:
# 13        4
# 14      141
# 15     2009
# 16     7830
# 17    21256
#       ...
# 73        2
# 75        2
# 76        1
# 77        1
# 82        1
# Name: NU_IDADE, Length: 65, dtype: int64

# %%
import matplotlib.pyplot as plt
import matplotlib.style as style

# Definir o estilo "dark"
style.use('dark_background')

dados['NU_IDADE'].hist(bins=20, figsize=(8,6), color='red')
plt.show()

# %%
#Mudar o gráfico acima usando o Chat GPT

# %% [markdown]
# ## Desejamos saber a distribuição da idade dos treineiros

# %%
treineiros = dados.query("IN_TREINEIRO == 1")
treineiros['NU_IDADE'].value_counts().sort_index()




#treineiros = dados.query("IN_TREINEIRO == 1")
#treineiros['NU_IDADE'].value_counts().sort_index()
#Plotar o histograma do gráfico das idades dos treineiros
# Out:
# 14      64
# 15    1927
# 16    7142
# 17    4901
# 18     858
# 19     228
# 20      83
# 21      44
# 22      30
# 23      21
# 24      13
# 25       8
# 26      13
# 27       9
# 28       6
# 29      10
# 30       4
# 31       4
# 32       2
# 33       1
# 34       3
# 35       2
# 36       2
# 37       1
# 38       4
# 39       2
# 40       4
# 41       1
# 42       4
# 44       2
# 45       1
# 46       2
# 47       1
# 48       1
# 51       1
# 55       1
# 62       1
# Name: NU_IDADE, dtype: int64

# %%
#dados.query("IN_TREINEIRO == 1")["NU_IDADE"].value_counts().sort_index()
# Out:
# 14      64
# 15    1927
# 16    7142
# 17    4901
# 18     858
# 19     228
# 20      83
# 21      44
# 22      30
# 23      21
# 24      13
# 25       8
# 26      13
# 27       9
# 28       6
# 29      10
# 30       4
# 31       4
# 32       2
# 33       1
# 34       3
# 35       2
# 36       2
# 37       1
# 38       4
# 39       2
# 40       4
# 41       1
# 42       4
# 44       2
# 45       1
# 46       2
# 47       1
# 48       1
# 51       1
# 55       1
# 62       1
# Name: NU_IDADE, dtype: int64

# %%
nota_redacao = dados['NU_NOTA_REDACAO']
nota_redacao.hist(bins = 30, figsize = (10,8))
# Out:
# <Axes: >

# %%
provas = ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC','NU_NOTA_MT','NU_NOTA_REDACAO']

#Traçar histogramas no Ploty para cada uma das provas do banco de dados (dados) com atributo color pela coluna 'IN_TREINEIRO'

# %%
provas = ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
       'NU_NOTA_MT','NU_NOTA_REDACAO']
dados[provas].describe()
# Out:
#          NU_NOTA_CN    NU_NOTA_CH    NU_NOTA_LC    NU_NOTA_MT  NU_NOTA_REDACAO
# count  92758.000000  98043.000000  98043.000000  92758.000000     98043.000000
# mean     477.964015    507.365912    520.463928    523.555206       571.570025
# std       76.296099     82.972839     64.556578    109.416939       188.076455
# min        0.000000      0.000000      0.000000      0.000000         0.000000
# 25%      418.000000    447.900000    483.700000    435.300000       480.000000
# 50%      470.200000    510.900000    526.100000    501.600000       580.000000
# 75%      533.300000    567.100000    565.100000    598.200000       680.000000
# max      797.300000    809.400000    801.700000    985.000000      1000.000000

# %%
import pandas as pd

# Supondo que 'dados' seja o seu DataFrame e 'provas' a lista de colunas das notas
provas = ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO']

# Criando a coluna 'NU_NOTA_TOTAL' como a soma das notas das provas
dados['NU_NOTA_TOTAL'] = dados[provas].sum(axis=1)

# Verificando as estatísticas descritivas das notas das provas
dados
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0       190001004661    2019                  1506138                Redenção
# 1       190001004674    2019                  1504208                  Marabá
# 2       190001004722    2019                  1501402                   Belém
# 3       190001004735    2019                  1507300      São Félix do Xingu
# 4       190001004776    2019                  1500800              Ananindeua
# ...              ...     ...                      ...                     ...
# 127375  190006120035    2019                  3142700             Montalvânia
# 127376  190006120036    2019                  2902807         Barra da Estiva
# 127377  190006120037    2019                  2927408                Salvador
# 127378  190006120060    2019                  2930709            Simões Filho
# 127379  190006120170    2019                  3106200          Belo Horizonte
#
# ...

# %%
dados[["NU_NOTA_REDACAO","NU_NOTA_LC"]].describe()
# Out:
#        NU_NOTA_REDACAO    NU_NOTA_LC
# count     98043.000000  98043.000000
# mean        571.570025    520.463928
# std         188.076455     64.556578
# min           0.000000      0.000000
# 25%         480.000000    483.700000
# 50%         580.000000    526.100000
# 75%         680.000000    565.100000
# max        1000.000000    801.700000

# %%
import matplotlib.pyplot as plt

style.use('default')

dados[provas].plot.box(grid=True, figsize=(8, 6))
plt.show()

# %%
dados[provas].plot.box(grid = True, figsize = (10,8))
# Out:
# <Axes: >

# %% [markdown]
# # SeaBorn

# %%
dados_idade_13_15 = dados.query("NU_IDADE >=13 and NU_IDADE <= 15")
dados_idade_13_15['SG_UF_RESIDENCIA'].value_counts()
# Out:
# SP    308
# MG    219
# PE    185
# BA    166
# CE    165
# PA    136
# GO    112
# MA     98
# PB     87
# PR     82
# RJ     71
# PI     65
# MT     52
# RS     44
# MS     41
# SE     41
# TO     38
# AL     38
# AM     38
# SC     35
# DF     33
# ES     26
# RN     26
# RO     20
# AP     17
# AC      7
# RR      4
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
dados.query("NU_IDADE <= 14")['SG_UF_RESIDENCIA'].value_counts()
# Out:
# PE    18
# CE    15
# BA    14
# PA    12
# MG    11
# SP    11
# MA     9
# PI     7
# GO     7
# PB     7
# MT     4
# AM     4
# DF     4
# TO     3
# SE     3
# PR     3
# AL     2
# RO     2
# SC     2
# AP     1
# RN     1
# ES     1
# AC     1
# RS     1
# RJ     1
# MS     1
# Name: SG_UF_RESIDENCIA, dtype: int64

# %%
dados.query("NU_IDADE <= 14")["SG_UF_RESIDENCIA"].value_counts(normalize = True)
# Out:
# PE    0.124138
# CE    0.103448
# BA    0.096552
# PA    0.082759
# MG    0.075862
# SP    0.075862
# MA    0.062069
# PI    0.048276
# GO    0.048276
# PB    0.048276
# MT    0.027586
# AM    0.027586
# DF    0.027586
# TO    0.020690
# SE    0.020690
# PR    0.020690
# AL    0.013793
# RO    0.013793
# SC    0.013793
# AP    0.006897
# RN    0.006897
# ES    0.006897
# AC    0.006897
# RS    0.006897
# RJ    0.006897
# MS    0.006897
# Name: SG_UF_RESIDENCIA, dtype: float64

# %%
alunos_menor_quatorze = dados.query("NU_IDADE <= 14")
alunos_menor_quatorze["SG_UF_RESIDENCIA"].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
alunos_menor_quatorze["SG_UF_RESIDENCIA"].value_counts().plot.bar(figsize=(10,8))
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

dados_PE = dados.query('SG_UF_RESIDENCIA == "PE"')

dados_PE
# Out:
#         NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA  \
# 3736    190001151401    2019                  2612208
# 3973    190001160185    2019                  2604304
# 4091    190001164983    2019                  2611101
# 4712    190001188391    2019                  2603926
# 6177    190001246185    2019                  2607901
# ...              ...     ...                      ...
# 127321  190006117185    2019                  2612406
# 127350  190006118551    2019                  2611606
# 127351  190006118552    2019                  2604106
# 127352  190006118561    2019                  2600807
# 127372  190006119915    2019                  2611606
#
#         NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE  \
# 3736                  Salgueiro                26               PE        18
# 3973                      Cedro                26               PE        19
# 4091                  Petrolina                26               PE        27
# ...

# %%
rendas = dados['Q006'].unique()
renda_ordenada = sorted(rendas)

# %%
plt.figure(figsize = (15,12))
sns.boxplot(x = "Q006", y = "NU_NOTA_MT", data = dados, order = renda_ordenada, hue = 'IN_TREINEIRO')
plt.title("Boxplot das notas de MT pela renda")



#plt.figure(figsize = (15,12))
#sns.boxplot(x = "Q006", y = "NU_NOTA_MT", data = dados)
#plt.title("Boxplot das notas de matemática pela renda")
# Out:
# Text(0.5, 1.0, 'Boxplot das notas de MT pela renda')

# %%
dados.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        'TP_NACIONALIDADE', 'CO_MUNICIPIO_NASCIMENTO',
#        'NO_MUNICIPIO_NASCIMENTO', 'CO_UF_NASCIMENTO', 'SG_UF_NASCIMENTO',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_ESCOLA', 'CO_MUNICIPIO_ESC',
#        'NO_MUNICIPIO_ESC', 'CO_UF_ESC', 'SG_UF_ESC',
#        'TP_DEPENDENCIA_ADM_ESC', 'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC',
#        'IN_BAIXA_VISAO', 'IN_CEGUEIRA', 'IN_SURDEZ',
#        'IN_DEFICIENCIA_AUDITIVA', 'IN_SURDO_CEGUEIRA',
#        'IN_DEFICIENCIA_FISICA', 'IN_DEFICIENCIA_MENTAL',
#        'IN_DEFICIT_ATENCAO', 'IN_DISLEXIA', 'IN_DISCALCULIA',
#        'IN_AUTISMO', 'IN_VISAO_MONOCULAR', 'IN_OUTRA_DEF', 'IN_GESTANTE',
#        'IN_LACTANTE', 'IN_IDOSO', 'IN_ESTUDA_CLASSE_HOSPITALAR',
# ...

# %%
plt.figure(figsize = (10,8))
sns.boxplot(x = "Q006", y = "NU_NOTA_MT", data = dados, order = renda_ordenada)
plt.title("Boxplot das notas de matemática pela renda")
# Out:
# Text(0.5, 1.0, 'Boxplot das notas de matemática pela renda')

# %%
#axis = 0 Soma por coluna
dados[provas].sum(axis = 0)
# Out:
# NU_NOTA_CN         44334986.1
# NU_NOTA_CH         49743676.1
# NU_NOTA_LC         51027844.9
# NU_NOTA_MT         48563933.8
# NU_NOTA_REDACAO    56038440.0
# dtype: float64

# %%
plt.figure(figsize = (10,8))
sns.boxplot(x = "Q006", y = "NU_NOTA_TOTAL", data = dados, order = renda_ordenada)
plt.title("Boxplot das notas total pela renda")
# Out:
# Text(0.5, 1.0, 'Boxplot das notas total pela renda')

# %%
sns.displot(dados, x = "NU_NOTA_TOTAL")

# %%
provas
# Out:
# ['NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC', 'NU_NOTA_MT', 'NU_NOTA_REDACAO']

# %%
provas.append("NU_NOTA_TOTAL")
dados[provas].query("NU_NOTA_TOTAL == 0")
# Out:
#         NU_NOTA_CN  NU_NOTA_CH  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_REDACAO  \
# 10             NaN         NaN         NaN         NaN              NaN
# 11             NaN         NaN         NaN         NaN              NaN
# 26             NaN         NaN         NaN         NaN              NaN
# 38             NaN         NaN         NaN         NaN              NaN
# 40             NaN         NaN         NaN         NaN              NaN
# ...            ...         ...         ...         ...              ...
# 127351         NaN         NaN         NaN         NaN              NaN
# 127365         NaN         NaN         NaN         NaN              NaN
# 127366         NaN         NaN         NaN         NaN              NaN
# 127368         NaN         NaN         NaN         NaN              NaN
# 127374         NaN         NaN         NaN         NaN              NaN
#
#         NU_NOTA_TOTAL
# 10                0.0
# 11                0.0
# 26                0.0
# ...

# %%
dados_sem_notas_zero = dados.query("NU_NOTA_TOTAL != 0")
dados_sem_notas_zero.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0  190001004661    2019                  1506138                Redenção
# 1  190001004674    2019                  1504208                  Marabá
# 2  190001004722    2019                  1501402                   Belém
# 3  190001004735    2019                  1507300      São Félix do Xingu
# 4  190001004776    2019                  1500800              Ananindeua
#
#    CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0                15               PA        17       M                1
# 1                15               PA        23       M                1
# 2                15               PA        35       F                2
# 3                15               PA        23       F                1
# 4                15               PA        16       F                1
#
#    TP_COR_RACA  ...  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025  \
# ...

# %%
plt.figure(figsize = (10,8))
sns.boxplot(x = "Q006", y = "NU_NOTA_TOTAL", data = dados_sem_notas_zero, order = sorted(renda_ordenada))
plt.title("Boxplot das notas total pela renda")
# Out:
# Text(0.5, 1.0, 'Boxplot das notas total pela renda')

# %%
plt.figure(figsize = (20,10))
sns.boxplot(x = "Q006", y = "NU_NOTA_TOTAL", data = dados_sem_notas_zero, hue = "IN_TREINEIRO", order = renda_ordenada)
plt.title("Boxplot das notas total pela renda")
# Out:
# Text(0.5, 1.0, 'Boxplot das notas total pela renda')

# %% [markdown]
# # Histograma e Correlação no Seaborn

# %%
#Ter o não ter internet - 'Q025'
plt.figure(figsize = (12,10))
sns.histplot(data = dados_sem_notas_zero, x = 'NU_NOTA_TOTAL', hue = 'Q025', kde = True)
#sns.histplot(data = dados_sem_notas_zero, x = "NU_NOTA_TOTAL", hue = "Q025", kde = True)

#A = Não tem internet
#B = Tem internet
# Out:
# <Axes: xlabel='NU_NOTA_TOTAL', ylabel='Count'>

# %%
correlacao = dados_sem_notas_zero[provas].corr()
sns.heatmap(correlacao, annot = True)
# Out:
# <Axes: >
