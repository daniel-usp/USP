# %% [markdown]
# <a href="https://colab.research.google.com/github/daniel-usp/USP/blob/main/An%C3%A1lise_Regress%C3%A3o_Semead2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_excel("https://github.com/daniel-usp/USP/raw/main/imoveis.xlsx")
df
# Out:
#       valor_total  preco_m2  area_util  quartos  vagas  condominio  suites  \
# 0          189900   5934.38         32        2      1         180       0
# 1          221110   5142.09         43        2      1         250       0
# 2          219990   5116.05         43        1      1         300       0
# 3          219990   5116.05         43        2      1         300       0
# 4          220000   5365.85         41        2      1         300       0
# ...           ...       ...        ...      ...    ...         ...     ...
# 2254       255000  11590.91         22        1      0         200       1
# 2255       688000   4712.33        146        2      1         600       1
# 2256       275000   6875.00         40        1      0         382       0
# 2257       329000  11750.00         28        1      0         350       1
# 2258       254800  11581.82         22        1      0         200       1
#
#       banheiros  piscina  academia  quadra         dist
# ...

# %%
df.columns.values
# Out:
# array(['valor_total', 'preco_m2', 'area_util', 'quartos', 'vagas',
#        'condominio', 'suites', 'banheiros', 'piscina', 'academia',
#        'quadra', 'dist'], dtype=object)

# %%
import pandas as pd
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# Carregar os dados
df = pd.read_excel("https://github.com/daniel-usp/USP/raw/main/imoveis.xlsx")

# Preparar os dados
X = df[['preco_m2', 'area_util', 'banheiros', 'piscina', 'academia', 'quadra', 'dist']]
Y = df['valor_total']
X = sm.add_constant(X)  # Adiciona o termo constante

# Dividir os dados em conjuntos de treino e teste
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# Ajustar o modelo de regressão linear
model = sm.OLS(Y_train, X_train).fit()

# Exibir o resumo do modelo
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            valor_total   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                     3822.
# Date:                Fri, 10 Nov 2023   Prob (F-statistic):               0.00
# Time:                        15:17:55   Log-Likelihood:                -23836.
# No. Observations:                1807   AIC:                         4.769e+04
# Df Residuals:                    1799   BIC:                         4.773e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7.094e+05    1.1e+04    -64.696      0.000   -7.31e+05   -6.88e+05
# ...
